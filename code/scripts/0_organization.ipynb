# %% [markdown]
# # Code organization
#
# Additional reading can be found on the [Good Research Code Handbook / setup page](https://goodresearch.dev/setup)
#
# After this section, you will be able to:
#
# 1. Set up a CO capsule with a standard template for organizing data, code, and scripts
# 2.

# %%
making a change that will cause a merge conflict
